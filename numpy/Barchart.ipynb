# %%
import matplotlib.pyplot as plt

import pandas as pd


# Reading CSV file to Data Frame

df = pd.read_csv('NFHS-data.csv')


df1 = df[['Area', 'Population and Household Profile - Population below age 15 years (%)']]

df1.fillna(0, inplace=True)

plt.figure(figsize=(40,90))

df1.plot()

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')

plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([0,1,2,3],[1, 2, 3, 4], color='green', marker='o', linestyle='dashed',linewidth=2, markersize=12)
plt.ylabel('some numbers')
plt.show()
